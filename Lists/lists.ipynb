# %% [markdown]
# Data Organized
#
# Create List
#
# Add/Remove Data
#
# Access Data

# %% [markdown]
# scientists = ["naku","perfect","jphannes"]

# %%
scientists = ["Joha","Perfect","Naku"]

# %%
print(scientists[0])
# Out:
# Joha

# %%
scientists[0] = "rosa"

# %%
scientists
# Out:
# ['rosa', 'Perfect', 'Naku']

# %%
len(scientists)
# Out:
# 3

# %%
scientists.append("Johanna")

# %%
scientists
# Out:
# ['rosa', 'Perfect', 'Naku', 'Johanna']

# %%
scientists.insert(0,"tawana")

# %%
scientists
# Out:
# ['tawana', 'rosa', 'Perfect', 'Naku', 'Johanna']

# %%
alkalis = ["H","Li","Na","H","Rb"]

# %%
alkalis.remove("H")

# %%
alkalis
# Out:
# ['Li', 'Na', 'H', 'Rb']

# %%
alkalis.pop()
# Out:
# 'Rb'

# %%
alkalis
# Out:
# ['Li', 'Na', 'H']

# %%
alkalis.pop(0)
# Out:
# 'Li'

# %%
alkalis
# Out:
# ['Na', 'H']

# %%
alkalis.clear()

# %%
alkalis
# Out:
# []

# %%
alkalis = ["H","Li","Na","H","Rb"]

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for item in range(len(alkalis)):
    print(alkalis[item])
# Out:
# H
# Li
# Na
# H
# Rb

# %%
container = [2,3,4,5,6,7]

# %%
sum(container)
# Out:
# 27

# %%
min(container)
# Out:
# 2

# %%
max(container)
# Out:
# 7

# %%
container.sort()

# %%
container
# Out:
# [2, 3, 4, 5, 6, 7]

# %%
container.sort(reverse=True)

# %%
metals = ["iron","aluminium","silver","gold"]

# %%
temp = metals[0]

# %%
metals[0] =  metals[1]

# %%
metals[1] = temp

# %%
metals
# Out:
# ['aluminium', 'iron', 'silver', 'gold']

# %%
metals[1],metals[0] = metals[0],metals[1]

# %%
planets = [["Earth","" ,"Mars"],
["Venus","Mercury","Jupiter"],
["Saturn","Uranus","Neptune"]]

# %%
for i in range(len(planets)):
    for h in range(len(planets[i])):
     print(planets[i][h])
# Out:
# Earth
#
# Mars
# Venus
# Mercury
# Jupiter
# Saturn
# Uranus
# Neptune
